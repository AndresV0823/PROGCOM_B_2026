# %% [markdown]
# <a href="https://colab.research.google.com/github/AndresV0823/PROGCOM_B_2026/blob/main/EJERCICIOSAV.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#AREA DEL TRIANGULO
base=int(input("ingrese la base"))
altura=int(input("ingrese la altura"))
area=(base*altura)//2

print("El area del tragulo es:", area)2
# Out:
# ingrese la base2
# ingrese la altura2
# El area del tragulo es: 2

# %%
#Celsius
c=int(input("ingrese grados celsius"))
f=(c*9//5)+32
print("Grados fahrenheit",f)
# Out:
# ingrese grados celsius12
# Grados fahrenheit 53

# %%
#Promedio de 3
n1=int(input("ingrese numero 1:"))
n2=int(input("ingrese numero 2:"))
n3=int(input("ingrese numero 3:"))

prom=(n1+n2+n3)//3
print("El promedio es:", prom)
# Out:
# ingrese numero 1:6
# ingrese numero 2:6
# ingrese numero 3:6
# El promedio es: 6

# %%
#Area del circulor
radio=int(input("Ingrese el R"))
perimetro= 2*3* radio
area=3*radio*radio

print("Perimetro:", perimetro)
print("Area;", area)
# Out:
# Ingrese el R5
# Perimetro: 30
# Area; 75

# %%
#Ecuacion Cuadra
a=int(input("Ingrese a:"))
b=int(input("Ingrese b:"))
c=int(input("Ingrese c:"))

d=(b*b) - (4*a*c)
if d < 0:
 print("No tiene solucion")
else:
  raiz=int(d**0.5)

  x1=(-b+raiz)//(2*a)
  x2=(-b-raiz)//(2*a)

  print("x1=",x1)
  print("x2=",x2)
# Out:
# Ingrese a:45
# Ingrese b:65
# Ingrese c:12
# x1= -1
# x2= -2
