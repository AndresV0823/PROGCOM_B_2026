# %% [markdown]
# <a href="https://colab.research.google.com/github/AndresV0823/PROGCOM_B_2026/blob/main/ESTRUCTURAS_DE_SELECCION.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Estrucutas de seleccion
Evalua condiciones (su valor de verdad)

1.IF/ELSE
2 IF/ TENARIO
3 IF/ELIF/else
4 CASE

#if/else
Evalua una o mas condiciones, y dependiendo de su valor de verdad, realizara un accion u otra (solo dos acciones)

Sintaxis

if (condicion):
  si la condicion es verdadera se ejecuta este pedazo de codigo
  else:
    si la condicion es falsa, se ejecuta este pedazo de codigo

# %%
lluvia=input("esta lloviendo?")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-608854132.py in <cell line: 0>()
# ----> 1 lluvia=input("esta lloviendo?")
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# -> 1219                 raise KeyboardInterrupt("Interrupted by user") from None
#    1220             except Exception:
# ...

# %%
if lluvia=="sí" or lluvia=="si" or lluvias=="sí, muchisimo":
  print("use sombrilla. guarde la ropa :3")
else:
    print("salga tranquilo")
# Out:
# use sombrilla. guarde la ropa :3

# %%
## IF ternario
Sintaxis

variable=(codigo sin condicion es verdadera) if (condicion) else (codigo si condicion es falsa)
# Out:
#   File "/tmp/ipython-input-3002688305.py", line 4
#     variable=(codigo sin condicion es verdadera) if (condicion) else (codigo si condicion es falsa)
#               ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
aguacero = "Use sombrilla. Guarde la Ropa" if lluvia =="si" else "salga tranquilo"

# %%
print(aguacero)
# Out:
# Use sombrilla. Guarde la Ropa
